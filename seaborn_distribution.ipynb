# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt

# %%
# !pip install jupyterlab-lsp python-lsp-server
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupyterlab-lsp in c:\users\sajal\appdata\roaming\python\python313\site-packages (5.2.0)
# Requirement already satisfied: python-lsp-server in c:\users\sajal\appdata\roaming\python\python313\site-packages (1.14.0)
# Requirement already satisfied: jupyter_lsp>=2.0.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab-lsp) (2.3.0)
# Requirement already satisfied: jupyterlab<5.0.0a0,>=4.1.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab-lsp) (4.5.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (7.0.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.1.6)
# Requirement already satisfied: jupyter-core in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (5.9.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.2.4)
# Requirement already satisfied: packaging in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (25.0)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (79.0.0)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (6.5.2)
# Requirement already satisfied: traitlets in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (5.14.3)
# Requirement already satisfied: anyio in c:\users\sajal\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.25.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (4.11.0)
# Requirement already satisfied: certifi in c:\users\sajal\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.25.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\sajal\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.25.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.0.9)
# Requirement already satisfied: idna in c:\users\sajal\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.25.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.0.2)
# Requirement already satisfied: pyzmq>=24 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.9.0)
# Requirement already satisfied: babel>=2.10 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (4.25.1)
# Requirement already satisfied: requests>=2.31 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.32.3)
# Requirement already satisfied: docstring-to-markdown in c:\users\sajal\appdata\roaming\python\python313\site-packages (from python-lsp-server) (0.17)
# Requirement already satisfied: jedi<0.20.0,>=0.17.2 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from python-lsp-server) (0.19.2)
# Requirement already satisfied: pluggy>=1.0.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from python-lsp-server) (1.6.0)
# Requirement already satisfied: python-lsp-jsonrpc<2.0.0,>=1.1.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from python-lsp-server) (1.1.2)
# Requirement already satisfied: ujson>=3.0.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from python-lsp-server) (5.11.0)
# Requirement already satisfied: black in c:\users\sajal\appdata\roaming\python\python313\site-packages (from python-lsp-server) (26.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jedi<0.20.0,>=0.17.2->python-lsp-server) (0.8.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\sajal\appdata\roaming\python\python313\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (9.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (7.1.0)
# Requirement already satisfied: colorama in c:\users\sajal\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.4.6)
# Requirement already satisfied: decorator in c:\users\sajal\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\sajal\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.1.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\sajal\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\sajal\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.2.14)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jinja2>=3.0.3->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.27.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-core->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (4.5.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (6.0.3)
# Requirement already satisfied: rfc3339-validator in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\sajal\appdata\roaming\python\python313\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\sajal\appdata\roaming\python\python313\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\sajal\appdata\roaming\python\python313\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.21.2)
# Requirement already satisfied: six>=1.5 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.4.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\sajal\appdata\roaming\python\python313\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.23)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (4.15.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from black->python-lsp-server) (8.3.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from black->python-lsp-server) (1.1.0)
# Requirement already satisfied: pathspec>=1.0.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from black->python-lsp-server) (1.0.4)
# Requirement already satisfied: pytokens>=0.3.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from black->python-lsp-server) (0.4.1)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from docstring-to-markdown->python-lsp-server) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from importlib-metadata>=3.6->docstring-to-markdown->python-lsp-server) (3.23.0)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.9.0.20251008)
# Requirement already satisfied: executing>=1.2.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\sajal\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\sajal\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.2.3)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %config Completer.use_jedi = True

# %%
fig = plt.figure()
fig.add_axes([0.1,0.1,0.8,0.8])
# Out:
# <Axes: >

# %%
plt.savefig("basic.png")

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
sns.distplot(df['total_bill'], bins = 20)
# Out:
# C:\Users\sajal\AppData\Local\Temp\ipykernel_21956\3311616051.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill'], bins = 20)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
plt.subplot(1,2,1)
sns.distplot(df['total_bill'], bins = 20)
plt.subplot(1,2,2)
sns.distplot(df['tip'], bins = 20)
# Out:
# C:\Users\sajal\AppData\Local\Temp\ipykernel_21956\3548495240.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill'], bins = 20)
# C:\Users\sajal\AppData\Local\Temp\ipykernel_21956\3548495240.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['tip'], bins = 20)
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.jointplot(x = 'total_bill' , y = 'tip' , data = df, kind='scatter')

# %%
sns.pairplot(df, hue='sex')
